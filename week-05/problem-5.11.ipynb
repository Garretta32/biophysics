# %% [markdown]
# # Problem 5.11
#
# Use this notebook to present your work on the problem.  If you write scripts, store them in this folder and run them within this notebook to produce the requested histograms and graphs.

# %% [markdown]
# ## (a) Sums of random variables
#
# Write Python code to generate a histogram of 50,000 samples of a random variable $y = x_1 + x_2$ where $x_1$ and $x_2$ are random variables drawn from the uniform distribution over $[-1/2, 1/2]$.  Superimpose a plot of the expected probability distribution function for this variable.

# %%
# Garrett Allen
import numpy as np
import matplotlib.pyplot as plt
import scipy.special as ss
from scipy.special import binom
from numpy import random
from scipy.stats import norm
import math

# %%
samp = 5000

x1 = np.random.uniform(low=-0.5, high=0.5, size=(samp,))
x2 = np.random.uniform(low=-0.5, high=0.5, size=(samp,))
y = x1 + x2

# %%
mean = 0
sd = ((sum(y**2))/samp)**0.5
print("SD = ",sd)
bins = 500

count, bins, ignored = plt.hist(y, bins, density=True)
plt.plot(bins, 1/(sd * np.sqrt(2 * np.pi)) *
               np.exp( - (bins - mean)**2 / (2 * sd**2) ),
         linewidth=2, color='r')
plt.show()
# Out:
# SD =  0.41024492715729133

# %% [markdown]
# Write Python code to generate a histogram of 50,000 samples of a random variable $y = x_1 + x_2 + x_3 + x_4$ where $x_n$ are random variables drawn from the uniform distribution over $[-1/2, 1/2]$.  Superimpose a plot of the expected probability distribution function for this variable.

# %%
samp = 5000

x1 = np.random.uniform(low=-0.5, high=0.5, size=(samp,))
x2 = np.random.uniform(low=-0.5, high=0.5, size=(samp,))
x3 = np.random.uniform(low=-0.5, high=0.5, size=(samp,))
x4 = np.random.uniform(low=-0.5, high=0.5, size=(samp,))
y = x1 + x2 + x3 + x4

# %%
mean = 0
sd = ((sum(y**2))/samp)**0.5
print("SD = ",sd)
bins = 500

count, bins, ignored = plt.hist(y, bins, density=True)
plt.plot(bins, 1/(sd * np.sqrt(2 * np.pi)) *
               np.exp( - (bins - mean)**2 / (2 * sd**2) ),
         linewidth=2, color='r')
plt.show()
# Out:
# SD =  0.5739738117728514

# %% [markdown]
# ## (b) Sums of _more_ random variables
#
# Write Python code to generate a histogram of 50,000 samples of a random variable $y$ that is the sum of __10__ random variables drawn from the uniform distribution over $[-1/2, 1/2]$.  Superimpose a plot of the expected probability distribution function for this variable.

# %%
samp = 5000

x1 = np.random.uniform(low=-0.5, high=0.5, size=(samp,))
x2 = np.random.uniform(low=-0.5, high=0.5, size=(samp,))
x3 = np.random.uniform(low=-0.5, high=0.5, size=(samp,))
x4 = np.random.uniform(low=-0.5, high=0.5, size=(samp,))
x5 = np.random.uniform(low=-0.5, high=0.5, size=(samp,))
x6 = np.random.uniform(low=-0.5, high=0.5, size=(samp,))
x7 = np.random.uniform(low=-0.5, high=0.5, size=(samp,))
x8 = np.random.uniform(low=-0.5, high=0.5, size=(samp,))
x9 = np.random.uniform(low=-0.5, high=0.5, size=(samp,))
x10 = np.random.uniform(low=-0.5, high=0.5, size=(samp,))
y = x1 + x2 + x3 + x4 + x5 + x6 + x7 + x8 + x9 + x10

# %%
mean = 0
sd = ((sum(y**2))/samp)**0.5
print("SD = ",sd)
bins = 500

count, bins, ignored = plt.hist(y, bins, density=True)
plt.plot(bins, 1/(sd * np.sqrt(2 * np.pi)) *
               np.exp( - (bins - mean)**2 / (2 * sd**2) ),
         linewidth=2, color='r')
plt.show()
# Out:
# SD =  0.9073444094295372

# %% [markdown]
# ## (c) Sums of nonuniform discrete random variables
#
# rite Python code to generate a histogram of 50,000 samples of a random variables $y$ that are the sum of __2__, __4__, and __10__ random variables drawn from the discrete distribution
# $$
# P(1) = \dfrac{1}{3} \qquad P(2) = \dfrac{2}{9} \qquad P(3) = \dfrac{1}{9} \qquad P(4) = \dfrac{1}{3}
# $$

# %%
ysum = []
samp = 5000
for i in range(samp):
    xnew1 = 0
    xnew2 = 0
    xnew3 = 0
    xnew4 = 0

    x1 = np.random.uniform(low=0, high=1)
    #print(x1)
    if x1 < (1/3):
        xnew1 = 1
    x2 = np.random.uniform(low=0, high=1)
    #print(x2)
    if x2 < (2/9):
        xnew2 = 2
    x3 = np.random.uniform(low=0, high=1)
    #print(x3)
    if x3 < (1/9):
        xnew3 = 3
    x4 = np.random.uniform(low=0, high=1)
    #print(x4)
    if x4 < (1/3):
        xnew4 = 4
    #print(xnew1,xnew2,xnew3,xnew4)
    y = xnew1 + xnew2 + xnew3 + xnew4
    #print(y)
    
    ysum = np.append(ysum,[y])

#print(ysum)

# %%
mean = (1*(1/3))+(2*(2/9))+(3*(1/9))+(4*(1/3))
sd = np.std(ysum)
print("SD = ",sd)
print("Mean = ",mean)
bins = 11

count, bins, ignored = plt.hist(ysum, bins, density=True)
plt.plot(bins, 1/(sd * np.sqrt(2 * np.pi)) *
               np.exp( - (bins - mean)**2 / (2 * sd**2) ),
         linewidth=2, color='r')
plt.show()
# Out:
# SD =  2.304642826990768
# Mean =  2.444444444444444

# %% [markdown]
# ## (d) Sums of nonuniform continuous random variables
#
# Write Python code to generate a histogram of 50,000 samples of a random variables $y$ that are the sum of __5__ and __50__ random variables drawn from the exponential distribution with expectation 1.

# %%
samp = 5000

x1 = np.random.uniform(low=0, high=2, size=(samp,))
x2 = np.random.uniform(low=0, high=2, size=(samp,))
x3 = np.random.uniform(low=0, high=2, size=(samp,))
x4 = np.random.uniform(low=0, high=2, size=(samp,))
x5 = np.random.uniform(low=0, high=2, size=(samp,))
y = x1 + x2 + x3 + x4 + x5

# %%
mean = 5
sd = np.std(y)
print("SD = ",sd)
bins = 500

count, bins, ignored = plt.hist(y, bins, density=True)
plt.plot(bins, 1/(sd * np.sqrt(2 * np.pi)) *
               np.exp( - (bins - mean)**2 / (2 * sd**2) ),
         linewidth=2, color='r')
plt.show()
# Out:
# SD =  1.2985277661488845

# %%
samp = 5000
y = 0

for i in range(50):
    x = np.random.uniform(low=0, high=2, size=(samp,))
    y = y + x

# %%
mean = 50
sd = np.std(y)
print("SD = ",sd)
bins = 500

count, bins, ignored = plt.hist(y, bins, density=True)
plt.plot(bins, 1/(sd * np.sqrt(2 * np.pi)) *
               np.exp( - (bins - mean)**2 / (2 * sd**2) ),
         linewidth=2, color='r')
plt.show()
# Out:
# SD =  4.038952559872986

# %% [markdown]
# ## Summarize your findings.

# %% [markdown]
# I only used 5000 samples becasue it was taking a long time to load any more.
#
# The greater the batch size the less likely points farout on the tails seem to occur. Which makes sense becasue the odds of getting 50 heads in a row is much less than getting 5 in a row.
